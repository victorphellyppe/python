# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
notas = pd.Series([2,7,5,10,6])

# %%
notas.values
notas.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
notas = pd.Series([2,7,5,10,6], index=["Alfredo","Maria","Joana","Daniel","Sandra"])
notas
# Out:
# Alfredo     2
# Maria       7
# Joana       5
# Daniel     10
# Sandra      6
# dtype: int64

# %%
#referenciando um determinado valor
notas["Maria"]
# Out:
# 7

# %%
notas.describe()
# Out:
# count     5.000000
# mean      6.000000
# std       2.915476
# min       2.000000
# 25%       5.000000
# 50%       6.000000
# 75%       7.000000
# max      10.000000
# dtype: float64

# %%
print("Média:", notas.mean())
# Out:
# Média: 6.0

# %%
print("Desvio padrão:", notas.std())
# Out:
# Desvio padrão: 2.9154759474226504

# %%
notas**2
# Out:
# Alfredo      4
# Maria       49
# Joana       25
# Daniel     100
# Sandra      36
# dtype: int64

# %%
df = pd.DataFrame({ "Alunos " : ["Alfredo","Maria","Joana","Daniel","Sandra"], "Faltas" : [3,4,2,1,4], "Prova" : [2,7,5,10,6], "Seminário" : [8.5,7.5,9.0,7.5,8.0]})
df
# Out:
#    Alunos   Faltas  Prova  Seminário
# 0  Alfredo       3      2        8.5
# 1    Maria       4      7        7.5
# 2    Joana       2      5        9.0
# 3   Daniel       1     10        7.5
# 4   Sandra       4      6        8.0

# %%
df.dtypes
# Out:
# Alunos        object
# Faltas         int64
# Prova          int64
# Seminário    float64
# dtype: object

# %%
#acessar a lista de colunas de forma bem intuitiva:
df.columns
# Out:
# Index(['Alunos ', 'Faltas', 'Prova', 'Seminário'], dtype='object')

# %%
#nomes das colunas podem ser usadas pra acessar seus valor
df['Seminário']
# Out:
# 0    8.5
# 1    7.5
# 2    9.0
# 3    7.5
# 4    8.0
# Name: Seminário, dtype: float64

# %%
df.sort_values(by="Prova")
# Out:
#    Alunos   Faltas  Prova  Seminário
# 0  Alfredo       3      2        8.5
# 2    Joana       2      5        9.0
# 4   Sandra       4      6        8.0
# 1    Maria       4      7        7.5
# 3   Daniel       1     10        7.5

# %%
#Manipulando os dados#######################
df["Prova"].unique()

# %%
df = pd.read_csv("dados.csv")
df
# Out:
#       condominio  quartos  suites  vagas  area    bairro    preco       pm2
# 0            350        1     0.0    1.0    21  Botafogo   340000  16190.48
# 1            800        1     0.0    1.0    64  Botafogo   770000  12031.25
# 2            674        1     0.0    1.0    61  Botafogo   600000   9836.07
# 3            700        1     1.0    1.0    70  Botafogo   700000  10000.00
# 4            440        1     0.0    1.0    44  Botafogo   515000  11704.55
# 5            917        1     1.0    1.0    60  Botafogo   630000  10500.00
# 6            850        1     1.0    1.0    65  Botafogo   740000  11384.62
# 7            350        1     1.0    1.0    43  Botafogo   570000  13255.81
# 8            440        1     1.0    1.0    26  Botafogo   430000  16538.46
# 9            510        1     1.0    1.0    42  Botafogo   500000  11904.76
# 10           200        1     0.0    1.0    35  Botafogo   500000  14285.71
# ...

# %%
df.head()
# Out:
#    condominio  quartos  suites  vagas  area    bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Botafogo  340000  16190.48
# 1         800        1     0.0    1.0    64  Botafogo  770000  12031.25
# 2         674        1     0.0    1.0    61  Botafogo  600000   9836.07
# 3         700        1     1.0    1.0    70  Botafogo  700000  10000.00
# 4         440        1     0.0    1.0    44  Botafogo  515000  11704.55

# %%
df.head(10)
# Out:
#    condominio  quartos  suites  vagas  area    bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Botafogo  340000  16190.48
# 1         800        1     0.0    1.0    64  Botafogo  770000  12031.25
# 2         674        1     0.0    1.0    61  Botafogo  600000   9836.07
# 3         700        1     1.0    1.0    70  Botafogo  700000  10000.00
# 4         440        1     0.0    1.0    44  Botafogo  515000  11704.55
# 5         917        1     1.0    1.0    60  Botafogo  630000  10500.00
# 6         850        1     1.0    1.0    65  Botafogo  740000  11384.62
# 7         350        1     1.0    1.0    43  Botafogo  570000  13255.81
# 8         440        1     1.0    1.0    26  Botafogo  430000  16538.46
# 9         510        1     1.0    1.0    42  Botafogo  500000  11904.76

# %%
df.tail()
# Out:
#       condominio  quartos  suites  vagas  area  bairro    preco      pm2
# 1992        1080        3     1.0    1.0    80  Tijuca   680000  8500.00
# 1993         750        3     0.0    1.0    82  Tijuca   650000  7926.83
# 1994         700        3     1.0    1.0   100  Tijuca   629900  6299.00
# 1995        1850        3     1.0    2.0   166  Tijuca  1600000  9638.55
# 1996         800        3     1.0    1.0   107  Tijuca   540000  5046.73

# %%
df["bairro"].unique()
# Out:
# array(['Botafogo', 'Copacabana', 'Gávea', 'Grajaú', 'Ipanema', 'Leblon',
#        'Tijuca'], dtype=object)

# %%
df["bairro"].value_counts()
# Out:
# Copacabana    346
# Tijuca        341
# Botafogo      307
# Ipanema       281
# Leblon        280
# Grajaú        237
# Gávea         205
# Name: bairro, dtype: int64

# %%
#médias agrupadas pelos valores da coluna bairros.
df.groupby("bairro").mean()
# Out:
#              condominio   quartos    suites     vagas        area  \
# bairro
# Botafogo     914.475570  2.107492  1.048860  1.159609   83.837134
# Copacabana   991.861272  2.101156  1.034682  1.080925  101.855491
# Grajaú       619.940928  2.097046  0.970464  1.130802   79.949367
# Gávea        985.234146  2.058537  1.029268  1.200000   88.497561
# Ipanema     1357.120996  2.181495  1.192171  1.220641  100.615658
# Leblon      1260.010714  2.207143  1.064286  1.164286   91.832143
# Tijuca       681.175953  2.131965  0.944282  1.143695   81.457478
#
#                    preco           pm2
# bairro
# Botafogo    1.010614e+06  12034.486189
# Copacabana  1.216344e+06  11965.298699
# Grajaú      4.788869e+05   6145.624473
# Gávea       1.454571e+06  16511.582780
# Ipanema     2.033096e+06  19738.407794
# Leblon      1.946193e+06  20761.351036
# Tijuca      5.750780e+05   7149.804985

# %%
#Funcao para retornar as 3 primeiras letras do bairro
def truncar(bairro):
    return bairro[:3]

df["bairro"].apply(truncar)
# Out:
# 0       Bot
# 1       Bot
# 2       Bot
# 3       Bot
# 4       Bot
# 5       Bot
# 6       Bot
# 7       Bot
# 8       Bot
# 9       Bot
# 10      Bot
# 11      Bot
# 12      Bot
# 13      Bot
# 14      Bot
# 15      Bot
# 16      Bot
# 17      Bot
# 18      Bot
# 19      Bot
# 20      Bot
# 21      Bot
# 22      Bot
# 23      Bot
# 24      Bot
# 25      Bot
# 26      Bot
# 27      Bot
# 28      Bot
# 29      Bot
#        ...
# 1967    Tij
# 1968    Tij
# 1969    Tij
# 1970    Tij
# 1971    Tij
# 1972    Tij
# 1973    Tij
# 1974    Tij
# 1975    Tij
# 1976    Tij
# 1977    Tij
# 1978    Tij
# 1979    Tij
# 1980    Tij
# 1981    Tij
# 1982    Tij
# 1983    Tij
# 1984    Tij
# 1985    Tij
# 1986    Tij
# 1987    Tij
# 1988    Tij
# 1989    Tij
# 1990    Tij
# 1991    Tij
# 1992    Tij
# 1993    Tij
# 1994    Tij
# 1995    Tij
# 1996    Tij
# Name: bairro, Length: 1997, dtype: object

# %%
df2 = df.head()
df2 = df2.replace({"pm2": {12031.25: np.nan}})
df2
# Out:
#    condominio  quartos  suites  vagas  area    bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Botafogo  340000  16190.48
# 1         800        1     0.0    1.0    64  Botafogo  770000       NaN
# 2         674        1     0.0    1.0    61  Botafogo  600000   9836.07
# 3         700        1     1.0    1.0    70  Botafogo  700000  10000.00
# 4         440        1     0.0    1.0    44  Botafogo  515000  11704.55

# %%
#remoção de quaiquer linhas ou colunas que possuem um NaN ou nulo
df2.dropna()
# Out:
#    condominio  quartos  suites  vagas  area    bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Botafogo  340000  16190.48
# 2         674        1     0.0    1.0    61  Botafogo  600000   9836.07
# 3         700        1     1.0    1.0    70  Botafogo  700000  10000.00
# 4         440        1     0.0    1.0    44  Botafogo  515000  11704.55

# %%
#Preencher todos os valores NaN por um outro específico também é bastante simples
df2.fillna(9999)
# Out:
#    condominio  quartos  suites  vagas  area    bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Botafogo  340000  16190.48
# 1         800        1     0.0    1.0    64  Botafogo  770000   9999.00
# 2         674        1     0.0    1.0    61  Botafogo  600000   9836.07
# 3         700        1     1.0    1.0    70  Botafogo  700000  10000.00
# 4         440        1     0.0    1.0    44  Botafogo  515000  11704.55

# %%
#indicar valores nulos
df2.isna()
# Out:
#    condominio  quartos  suites  vagas   area  bairro  preco    pm2
# 0       False    False   False  False  False   False  False  False
# 1       False    False   False  False  False   False  False   True
# 2       False    False   False  False  False   False  False  False
# 3       False    False   False  False  False   False  False  False
# 4       False    False   False  False  False   False  False  False

# %%
#######################################Visualização de dados
#######verificar a distribuição dos preços
df["preco"].plot.hist()

# %%
#especificar a quantidade de bins, também especifiquei a cor das bordas 
df["preco"].plot.hist(bins=30, edgecolor='black')

# %%
#Plot de barras vertical
df["bairro"].value_counts().plot.bar()

# %%
#Plot de barras horizontal
df["bairro"].value_counts().plot.barh()
